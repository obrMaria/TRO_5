# %% [markdown]
# ## Самостоятельное задание
# #### Создать ноутбук, в котором выполнить решение вычислительной задачи (например, задачи из области физики, экономики, математики, статистики и т. д.) требующей построения столбчатой диаграммы, условие которой предварительно необходимо согласовать с преподавателем.

# %% [markdown]
# В книжном магазине проводится анализ по продажам.
#
# Имеются данные по кол-ву проданных эпических и драматических произведений.
#
# Нужно сравнить их продажи за последний месяц и определить, какой жанр литературы больше нравится покупателям
#
# Найти среднее количество проданных книг каждого жанра.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# данные по продажам книг за месяц
epic_book = [50, 150, 120, 90]
drama_book = [130, 120, 110, 100]

# %% [markdown]
# нахождение среднего количества проданных книг

# %%
sr_ep = sum(epic_book) / len(epic_book)
sr_dr = sum(drama_book) / len(drama_book)

# %%
print("Среднее кол-во проданных эпических произведений:", sr_ep)
print("Среднее кол-во проданных драматических произведений:", sr_dr)
# Out:
# Среднее кол-во проданных эпических произведений: 102.5
# Среднее кол-во проданных драматических произведений: 115.0

# %% [markdown]
# построим столбчатый график
#
# добавление подписей к графику

# %%
labels = ['Неделя 1', 'Неделя 2', 'Неделя 3', 'Неделя 4']

x = np.arange(len(labels))
width = 0.3

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, adventures_book, width, label='Эпические')
rects2 = ax.bar(x + width/2, drama_book, width, label='драма')

ax.set_ylabel('Количество проданных книг')
ax.set_xlabel('Недели')
ax.set_title('Продажи книг за месяц')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()
